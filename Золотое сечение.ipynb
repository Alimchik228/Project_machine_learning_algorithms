# %%
import math as m
def f(x):
    return ((1/3)*3.14159*x**2*((1600-x**2)**(1/2)+40))

# %%
a = 0
b = 40
c,d=0, 0

# %%
def iter(a,b,c,d):
    d = a+(b-a)*(5**(1/2)-1)/2
    c = b-(b-a)*(5**(1/2)-1)/2
    if f(d)>f(c):
        a=c
    else:
        b=d
    return (a,b,c,d)

# %%
i=0
while abs(b-a) > 0.0001:
    i+=1
    a,b,c,d = iter(a,b,c,d)
    iter(a,b,c,d)
    print("{}, {}, {}, {}, {}, {}, {}, {}".format(i, a, b, a-b, c, d, f(c), f(d)))
# Out:
# 1, 15.278640450004204, 40, -24.721359549995796, 15.278640450004204, 24.721359549995796, 18805.404685014953, 45701.59420091247
# 2, 24.72135954999579, 40, -15.278640450004211, 24.72135954999579, 30.557280900008415, 45701.594200912456, 64319.406928246
# 3, 30.557280900008408, 40, -9.442719099991592, 30.557280900008408, 34.16407864998738, 64319.406928245975, 74281.65452994501
# 4, 34.16407864998738, 40, -5.835921350012619, 34.16407864998738, 36.39320225002103, 74281.65452994501, 78462.03162148084
# 5, 36.39320225002103, 40, -3.6067977499789734, 36.39320225002103, 37.770876399966355, 78462.03162148084, 79389.28363070918
# 6, 36.39320225002103, 38.62232585005468, -2.2291236000336525, 37.77087639996635, 38.62232585005468, 79389.2836307092, 78701.01866526571
# 7, 37.24465170010936, 38.62232585005468, -1.377674149945321, 37.24465170010936, 37.77087639996635, 79257.53263293285, 79389.2836307092
# ...

# %%
f(x1, x2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4524/132903710.py in <module>
# ----> 1 f(x1, x2)
#
# NameError: name 'f' is not defined
